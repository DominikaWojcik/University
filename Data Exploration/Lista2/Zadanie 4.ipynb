# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Z TW COSINUSOW MOZEMY WYLICZYC PROMIEN WIELOKATA FOREMNEGO O BOKU d
#
# r = sqrt(d^2 / (2*(1 - cos(alfa))))
#
def generateRandom(K, d):
    pointsInCloud = 1000
    alpha = 2.* np.pi / K
    r = np.sqrt(d**2 / (2*(1 - np.cos(alpha))))
    vec = np.array([[r],[0.]])
    rotMatrix = np.array([[np.cos(alpha), -np.sin(alpha)], [np.sin(alpha), np.cos(alpha)]])
    
    data = []
    for i in range(K):
        a = vec[0][0]
        b = vec[1][0]
        sigma = 1.
        
        X = np.random.normal(a, sigma, pointsInCloud)
        Y = np.random.normal(b, sigma, pointsInCloud)
        data.append((vec, X, Y))
        
        color = np.random.rand(3,1)
        plt.scatter(X, Y, c=color, marker='.', lw = 0)
    
        vec = np.dot(rotMatrix, vec)
    plt.show()
    return data

# %%
data = generateRandom(7,5)

# %%
data = generateRandom(7, 10)

# %%
data = generateRandom(7,15)

# %%
data = generateRandom(11,5)

# %%
data = generateRandom(11,10)

# %%
data = generateRandom(11,15)

# %%
data = generateRandom(23,5)

# %%
data = generateRandom(23,10)

# %%
data = generateRandom(23,15)
